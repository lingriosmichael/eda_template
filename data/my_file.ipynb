# %% [markdown]
# ## Requirement, Structure of the task, Import Data
#
# # Requirements of Amy
# Amy Williams        | Seller      | Mafiosi, sells several central houses(top10%) over time, needs average outskirt houses over time to hide from the FBI
#
# # Important Columns of Data Set (Roland)
# - **dateDate** - date the house was sold
# - **pricePrice** - prediction targe
# - **yr_built** - Built Year
# - **yr_renovated** - Year when house was renovated
# - **zipcode** - zip
# - **lat** - Latitude coordinate
# - **long** - Longitude coordinate
#
#
#
# What is central?
# What is outskirt?
# What is 10%? luxorious?
# The price sold over time? (to analyse the best time? Seasons when the houses where sold)
# - We need the date?
# - We need the price?
# - What is central?
#
#
#
# # Column Names and descriptions for King County Data Set
# - **id** - unique identifier for a house
# - **dateDate** - date the house was sold
# - **pricePrice** - prediction target
# - **bedroomsNumber** - # of bedrooms
# - **bathroomsNumber** - # of bathrooms
# - **sqft_livingsquare** - footage of the home
# - **sqft_lotsquare** - footage of the lot
# - **floorsTotal** - floors (levels) in house
# - **waterfront** - House which has a view to a waterfront
# - **view** - quality of view
# - **condition** - How good the condition is ( Overall )
# - **grade** - overall grade given to the housing unit, based on King County grading system
# - **sqft_above** - square footage of house apart from basement
# - **sqft_basement** - square footage of the basement
# - **yr_built** - Built Year
# - **yr_renovated** - Year when house was renovated
# - **zipcode** - zip
# - **lat** - Latitude coordinate
# - **long** - Longitude coordinate
# - **sqft_living15** - The square footage of interior housing living space for the nearest 15 neighbors
# - **sqft_lot15** - The square footage of the land lots of the nearest 15 neighbors

# %%
import numpy as np
import pandas as pd

# %%
# importing raw data

df_amy = pd.read_csv("/Users/rolandelsaesser/neuefische_course/eda_template/data/dataset.csv")
df_copy = df_amy.copy()

# %%
# your code: check for data types and statistics overview of data frame columns

# 1. Check data types, non-null counts, and memory usage
print("--- Data Info ---")
df_copy.info()
# Out:
# --- Data Info ---
# <class 'pandas.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           21597 non-null  str
#  1   price          21597 non-null  float64
#  2   house_id       21597 non-null  int64
#  3   id             21597 non-null  int64
#  4   id.1           21597 non-null  int64
#  5   bedrooms       21597 non-null  float64
#  6   bathrooms      21597 non-null  float64
#  7   sqft_living    21597 non-null  float64
#  8   sqft_lot       21597 non-null  float64
#  9   floors         21597 non-null  float64
#  10  waterfront     19206 non-null  float64
#  11  view           21534 non-null  float64
#  12  condition      21597 non-null  int64
#  13  grade          21597 non-null  int64
#  14  sqft_above     21597 non-null  float64
#  15  sqft_basement  21145 non-null  float64
#  16  yr_built       21597 non-null  int64
#  17  yr_renovated   17749 non-null  float64
#  18  zipcode        21597 non-null  int64
#  19  lat            21597 non-null  float64
#  20  long           21597 non-null  float64
#  21  sqft_living15  21597 non-null  float64
#  22  sqft_lot15     21597 non-null  float64
# dtypes: float64(15), int64(7), str(1)
# memory usage: 3.8 MB

# %%
# 2. Get statistical summary for numerical columns
print("\n--- Numerical Summary ---")
display(df_copy.describe())
# Out:
# --- Numerical Summary ---
#               price      house_id            id          id.1      bedrooms  \
# count  2.159700e+04  2.159700e+04  21597.000000  2.159700e+04  21597.000000
# mean   5.402966e+05  4.580474e+09  10799.000000  4.580474e+09      3.373200
# std    3.673681e+05  2.876736e+09   6234.661218  2.876736e+09      0.926299
# min    7.800000e+04  1.000102e+06      1.000000  1.000102e+06      1.000000
# 25%    3.220000e+05  2.123049e+09   5400.000000  2.123049e+09      3.000000
# 50%    4.500000e+05  3.904930e+09  10799.000000  3.904930e+09      3.000000
# 75%    6.450000e+05  7.308900e+09  16198.000000  7.308900e+09      4.000000
# max    7.700000e+06  9.900000e+09  21597.000000  9.900000e+09     33.000000
#
#           bathrooms   sqft_living      sqft_lot        floors    waterfront  \
# count  21597.000000  21597.000000  2.159700e+04  21597.000000  19206.000000
# mean       2.115826   2080.321850  1.509941e+04      1.494096      0.007602
# std        0.768984    918.106125  4.141264e+04      0.539683      0.086858
# min        0.500000    370.000000  5.200000e+02      1.000000      0.000000
# 25%        1.750000   1430.000000  5.040000e+03      1.000000      0.000000
# 50%        2.250000   1910.000000  7.618000e+03      1.500000      0.000000
# 75%        2.500000   2550.000000  1.068500e+04      2.000000      0.000000
# max        8.000000  13540.000000  1.651359e+06      3.500000      1.000000
#
#        ...         grade    sqft_above  sqft_basement      yr_built  \
# count  ...  21597.000000  21597.000000   21145.000000  21597.000000
# mean   ...      7.657915   1788.596842     291.857224   1970.999676
# std    ...      1.173200    827.759761     442.490863     29.375234
# min    ...      3.000000    370.000000       0.000000   1900.000000
# 25%    ...      7.000000   1190.000000       0.000000   1951.000000
# 50%    ...      7.000000   1560.000000       0.000000   1975.000000
# 75%    ...      8.000000   2210.000000     560.000000   1997.000000
# max    ...     13.000000   9410.000000    4820.000000   2015.000000
#
#        yr_renovated       zipcode           lat          long  sqft_living15  \
# count  17749.000000  21597.000000  21597.000000  21597.000000   21597.000000
# mean     836.650516  98077.951845     47.560093   -122.213983    1986.620318
# std     4000.110554     53.513072      0.138552      0.140724     685.230472
# min        0.000000  98001.000000     47.155900   -122.519000     399.000000
# 25%        0.000000  98033.000000     47.471100   -122.328000    1490.000000
# 50%        0.000000  98065.000000     47.571800   -122.231000    1840.000000
# 75%        0.000000  98118.000000     47.678000   -122.125000    2360.000000
# max    20150.000000  98199.000000     47.777600   -121.315000    6210.000000
#
#           sqft_lot15
# count   21597.000000
# mean    12758.283512
# std     27274.441950
# min       651.000000
# 25%      5100.000000
# 50%      7620.000000
# 75%     10083.000000
# max    871200.000000
#
# [8 rows x 22 columns]

# %%
# 3. Get statistical summary for categorical/object columns
# (This helps find unique counts and the most frequent labels)
print("\n--- Categorical Summary ---")
display(df_copy.describe(include='object'))
# Out:
# --- Categorical Summary ---
# /var/folders/5l/l8tzy9cx1ms0sx8q3bytdn9r0000gn/T/ipykernel_11734/2054843459.py:4: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   display(df_copy.describe(include='object'))
#               date
# count        21597
# unique         372
# top     2014-06-23
# freq           142

# %%
# 4. Explicitly check for missing values count per column
print("\n--- Missing Values ---")
print(df_copy.isnull().sum())
# Out:
# --- Missing Values ---
# date                0
# price               0
# house_id            0
# id                  0
# id.1                0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2391
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement     452
# yr_built            0
# yr_renovated     3848
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
df_copy.head(5)
# Out:
#          date     price    house_id  id        id.1  bedrooms  bathrooms  \
# 0  2014-10-13  221900.0  7129300520   1  7129300520       3.0       1.00
# 1  2014-12-09  538000.0  6414100192   2  6414100192       3.0       2.25
# 2  2015-02-25  180000.0  5631500400   3  5631500400       2.0       1.00
# 3  2014-12-09  604000.0  2487200875   4  2487200875       4.0       3.00
# 4  2015-02-18  510000.0  1954400510   5  1954400510       3.0       2.00
#
#    sqft_living  sqft_lot  floors  ...  grade  sqft_above  sqft_basement  \
# 0       1180.0    5650.0     1.0  ...      7      1180.0            0.0
# 1       2570.0    7242.0     2.0  ...      7      2170.0          400.0
# 2        770.0   10000.0     1.0  ...      6       770.0            0.0
# 3       1960.0    5000.0     1.0  ...      7      1050.0          910.0
# 4       1680.0    8080.0     1.0  ...      8      1680.0            0.0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955           0.0    98178  47.5112 -122.257         1340.0
# 1      1951       19910.0    98125  47.7210 -122.319         1690.0
# 2      1933           NaN    98028  47.7379 -122.233         2720.0
# 3      1965           0.0    98136  47.5208 -122.393         1360.0
# 4      1987           0.0    98074  47.6168 -122.045         1800.0
#
#    sqft_lot15
# 0      5650.0
# 1      7639.0
# 2      8062.0
# 3      5000.0
# 4      7503.0
#
# [5 rows x 23 columns]

# %%
# dropping unwanted columns for further analysis (id, id.1, sqft_above, sqft_basement, sqft_living15, sqft_lot15)
df_copy= df_copy.drop(columns=['id', 'id.1', 'sqft_above', 'sqft_basement', 'sqft_living15', 'sqft_lot15'])

# %%
df_copy.head(5)
# Out:
#          date     price    house_id  bedrooms  bathrooms  sqft_living  \
# 0  2014-10-13  221900.0  7129300520       3.0       1.00       1180.0
# 1  2014-12-09  538000.0  6414100192       3.0       2.25       2570.0
# 2  2015-02-25  180000.0  5631500400       2.0       1.00        770.0
# 3  2014-12-09  604000.0  2487200875       4.0       3.00       1960.0
# 4  2015-02-18  510000.0  1954400510       3.0       2.00       1680.0
#
#    sqft_lot  floors  waterfront  view  condition  grade  yr_built  \
# 0    5650.0     1.0         NaN   0.0          3      7      1955
# 1    7242.0     2.0         0.0   0.0          3      7      1951
# 2   10000.0     1.0         0.0   0.0          3      6      1933
# 3    5000.0     1.0         0.0   0.0          5      7      1965
# 4    8080.0     1.0         0.0   0.0          3      8      1987
#
#    yr_renovated  zipcode      lat     long
# 0           0.0    98178  47.5112 -122.257
# 1       19910.0    98125  47.7210 -122.319
# 2           NaN    98028  47.7379 -122.233
# 3           0.0    98136  47.5208 -122.393
# 4           0.0    98074  47.6168 -122.045

# %%
# dropping unwanted columns for further analysis (yr_renovated))
df_copy= df_copy.drop(columns=['yr_renovated'])

# %%
df_copy.head(5)
# Out:
#          date     price    house_id  bedrooms  bathrooms  sqft_living  \
# 0  2014-10-13  221900.0  7129300520       3.0       1.00       1180.0
# 1  2014-12-09  538000.0  6414100192       3.0       2.25       2570.0
# 2  2015-02-25  180000.0  5631500400       2.0       1.00        770.0
# 3  2014-12-09  604000.0  2487200875       4.0       3.00       1960.0
# 4  2015-02-18  510000.0  1954400510       3.0       2.00       1680.0
#
#    sqft_lot  floors  waterfront  view  condition  grade  yr_built  zipcode  \
# 0    5650.0     1.0         NaN   0.0          3      7      1955    98178
# 1    7242.0     2.0         0.0   0.0          3      7      1951    98125
# 2   10000.0     1.0         0.0   0.0          3      6      1933    98028
# 3    5000.0     1.0         0.0   0.0          5      7      1965    98136
# 4    8080.0     1.0         0.0   0.0          3      8      1987    98074
#
#        lat     long
# 0  47.5112 -122.257
# 1  47.7210 -122.319
# 2  47.7379 -122.233
# 3  47.5208 -122.393
# 4  47.6168 -122.045

# %%
df_copy.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         21597 non-null  str
#  1   price        21597 non-null  float64
#  2   house_id     21597 non-null  int64
#  3   bedrooms     21597 non-null  float64
#  4   bathrooms    21597 non-null  float64
#  5   sqft_living  21597 non-null  float64
#  6   sqft_lot     21597 non-null  float64
#  7   floors       21597 non-null  float64
#  8   waterfront   19206 non-null  float64
#  9   view         21534 non-null  float64
#  10  condition    21597 non-null  int64
#  11  grade        21597 non-null  int64
#  12  yr_built     21597 non-null  int64
#  13  zipcode      21597 non-null  int64
#  14  lat          21597 non-null  float64
#  15  long         21597 non-null  float64
# dtypes: float64(10), int64(5), str(1)
# memory usage: 2.6 MB

# %%
# in precipitation column, replace NaN with 0, in waterfront column
df_copy.fillna({"waterfront":0})
# Out:
#              date     price    house_id  bedrooms  bathrooms  sqft_living  \
# 0      2014-10-13  221900.0  7129300520       3.0       1.00       1180.0
# 1      2014-12-09  538000.0  6414100192       3.0       2.25       2570.0
# 2      2015-02-25  180000.0  5631500400       2.0       1.00        770.0
# 3      2014-12-09  604000.0  2487200875       4.0       3.00       1960.0
# 4      2015-02-18  510000.0  1954400510       3.0       2.00       1680.0
# ...           ...       ...         ...       ...        ...          ...
# 21592  2014-05-21  360000.0   263000018       3.0       2.50       1530.0
# 21593  2015-02-23  400000.0  6600060120       4.0       2.50       2310.0
# 21594  2014-06-23  402101.0  1523300141       2.0       0.75       1020.0
# 21595  2015-01-16  400000.0   291310100       3.0       2.50       1600.0
# 21596  2014-10-15  325000.0  1523300157       2.0       0.75       1020.0
#
#        sqft_lot  floors  waterfront  view  condition  grade  yr_built  \
# 0        5650.0     1.0         0.0   0.0          3      7      1955
# 1        7242.0     2.0         0.0   0.0          3      7      1951
# 2       10000.0     1.0         0.0   0.0          3      6      1933
# 3        5000.0     1.0         0.0   0.0          5      7      1965
# 4        8080.0     1.0         0.0   0.0          3      8      1987
# ...         ...     ...         ...   ...        ...    ...       ...
# 21592    1131.0     3.0         0.0   0.0          3      8      2009
# 21593    5813.0     2.0         0.0   0.0          3      8      2014
# 21594    1350.0     2.0         0.0   0.0          3      7      2009
# 21595    2388.0     2.0         0.0   0.0          3      8      2004
# 21596    1076.0     2.0         0.0   0.0          3      7      2008
#
#        zipcode      lat     long
# 0        98178  47.5112 -122.257
# 1        98125  47.7210 -122.319
# 2        98028  47.7379 -122.233
# 3        98136  47.5208 -122.393
# 4        98074  47.6168 -122.045
# ...        ...      ...      ...
# 21592    98103  47.6993 -122.346
# 21593    98146  47.5107 -122.362
# 21594    98144  47.5944 -122.299
# 21595    98027  47.5345 -122.069
# 21596    98144  47.5941 -122.299
#
# [21597 rows x 16 columns]

# %%
# The capital 'I' makes it the nullable integer type
df_copy['waterfront'] = df_copy['waterfront'].astype('Int64')

# %%
df_copy.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         21597 non-null  str
#  1   price        21597 non-null  float64
#  2   house_id     21597 non-null  int64
#  3   bedrooms     21597 non-null  float64
#  4   bathrooms    21597 non-null  float64
#  5   sqft_living  21597 non-null  float64
#  6   sqft_lot     21597 non-null  float64
#  7   floors       21597 non-null  float64
#  8   waterfront   19206 non-null  Int64
#  9   view         21534 non-null  float64
#  10  condition    21597 non-null  int64
#  11  grade        21597 non-null  int64
#  12  yr_built     21597 non-null  int64
#  13  zipcode      21597 non-null  int64
#  14  lat          21597 non-null  float64
#  15  long         21597 non-null  float64
# dtypes: Int64(1), float64(9), int64(5), str(1)
# memory usage: 2.7 MB

# %%
# display number of missing values per column
df_copy.isna().sum()
# Out:
# date              0
# price             0
# house_id          0
# bedrooms          0
# bathrooms         0
# sqft_living       0
# sqft_lot          0
# floors            0
# waterfront     2391
# view             63
# condition         0
# grade             0
# yr_built          0
# zipcode           0
# lat               0
# long              0
# dtype: int64

# %%
# Convert specific columns to int64
df_copy = df_copy.astype({
    'price': 'int64',
    'house_id': 'int64',
    'bedrooms': 'int64',
    'bathrooms': 'int64',
    'sqft_living': 'int64',
    'sqft_lot': 'int64',
    'floors': 'int64',
    'waterfront': 'int64',
    'view': 'int64',
    'condition': 'int64',
    'grade': 'int64'
})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 2
#       1 # Convert specific columns to int64
# ----> 2 df_copy = df_copy.astype({
#       3     'price': 'int64',
#       4     'house_id': 'int64',
#       5     'bedrooms': 'int64',
#       6     'bathrooms': 'int64',
#       7     'sqft_living': 'int64',
#       8     'sqft_lot': 'int64',
#       9     'floors': 'int64',
#      10     'waterfront': 'int64',
#      11     'view': 'int64',
#      12     'condition': 'int64',
#      13     'grade': 'int64'
#      14 })
#
# File ~/neuefische_course/eda_template/.venv_eda_project/lib/python3.11/site-packages/pandas/core/generic.py:6520, in NDFrame.astype(self, dtype, copy, errors)
#    6518 else:
#    6519     try:
# -> 6520         res_col = col.astype(dtype=cdt, errors=errors)
#    6521     except ValueError as ex:
#    6522         ex.args = (
#    6523             f"{ex}: Error while type casting for column '{col_name}'",
#    6524         )
#
# File ~/neuefische_course/eda_template/.venv_eda_project/lib/python3.11/site-packages/pandas/core/generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537     results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6539 else:
#    6540     # else, only a single dtype is given
# -> 6541     new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543     return res.__finalize__(self, method="astype")
#
# File ~/neuefische_course/eda_template/.venv_eda_project/lib/python3.11/site-packages/pandas/core/internals/managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
#     610 def astype(self, dtype, errors: str = "raise") -> Self:
# --> 611     return self.apply("astype", dtype=dtype, errors=errors)
#
# File ~/neuefische_course/eda_template/.venv_eda_project/lib/python3.11/site-packages/pandas/core/internals/managers.py:442, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     440         applied = b.apply(f, **kwargs)
#     441     else:
# --> 442         applied = getattr(b, f)(**kwargs)
#     443     result_blocks = extend_blocks(applied, result_blocks)
#     445 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File ~/neuefische_course/eda_template/.venv_eda_project/lib/python3.11/site-packages/pandas/core/internals/blocks.py:607, in Block.astype(self, dtype, errors, squeeze)
#     604         raise ValueError("Can not squeeze with more than one column.")
#     605     values = values[0, :]  # type: ignore[call-overload]
# --> 607 new_values = astype_array_safe(values, dtype, errors=errors)
#     609 new_values = maybe_coerce_values(new_values)
#     611 refs = None
#
# File ~/neuefische_course/eda_template/.venv_eda_project/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:240, in astype_array_safe(values, dtype, copy, errors)
#     237     dtype = dtype.numpy_dtype
#     239 try:
# --> 240     new_values = astype_array(values, dtype, copy=copy)
#     241 except (ValueError, TypeError):
#     242     # e.g. _astype_nansafe can fail on object-dtype of strings
#     243     #  trying to convert to float
#     244     if errors == "ignore":
#
# File ~/neuefische_course/eda_template/.venv_eda_project/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     178     return values
#     180 if not isinstance(values, np.ndarray):
#     181     # i.e. ExtensionArray
# --> 182     values = values.astype(dtype, copy=copy)
#     184 else:
#     185     values = _astype_nansafe(values, dtype, copy=copy)
#
# File ~/neuefische_course/eda_template/.venv_eda_project/lib/python3.11/site-packages/pandas/core/arrays/masked.py:684, in BaseMaskedArray.astype(self, dtype, copy)
#     682 # to_numpy will also raise, but we get somewhat nicer exception messages here
#     683 if dtype.kind in "iu" and self._hasna:
# --> 684     raise ValueError("cannot convert NA to integer")
#     685 if dtype.kind == "b" and self._hasna:
#     686     # careful: astype_nansafe converts np.nan to True
#     687     raise ValueError("cannot convert float NaN to bool")
#
# ValueError: cannot convert NA to integer: Error while type casting for column 'waterfront'
